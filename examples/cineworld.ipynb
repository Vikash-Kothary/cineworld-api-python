# %%
cd ..
# Out:
# /Users/vikash/Programming/vikash-kothary/cineworld-api-python

# %%
import cineworld_api

# %%
cineworld = cineworld_api.Client()

# %%
# Cinema
all_cinemas = cineworld.get_cinemas()
print(all_cinemas)
"""
for i in range(len(all_cinemas)):
    print(i)
    cinema = all_cinemas[i]
    print(cinema.id)
    print(cinema.name)
    print(cinema.available_dates)
    break
select_cinema = input('Cinema name:') or 'wembley'
cinema = cineworld.get_cinema(name=select_cinema)
"""
# Out:
# {'cinemas': [{'id': '8014', 'groupId': 'aberdeen', 'displayName': 'Aberdeen - Queens Links', 'link': '/cinemas/aberdeen-queens-links', 'imageUrl': '/static/dam/jcr:ac2e337f-ff5e-497f-8f36-56f92a216ffc', 'address': 'Queens Links Leisure Park, Links Road, AB24 5EN, Aberdeen', 'addressInfo': {'address1': 'Queens Links Leisure Park', 'address2': 'Links Road', 'address3': None, 'address4': None, 'city': 'Aberdeen', 'state': None, 'postalCode': 'AB24 5EN'}, 'bookingUrl': 'https://booking.cineworld.co.uk', 'blockOnlineSales': False, 'blockOnlineSalesUntil': None, 'latitude': 57.15026, 'longitude': -2.077969}, {'id': '8018', 'groupId': 'aberdeen', 'displayName': 'Aberdeen - Union Square', 'link': '/cinemas/aberdeen-union-square', 'imageUrl': '/static/dam/jcr:89bf328d-73d0-4539-9787-e2d64ea29188', 'address': 'Union Square, Guild Square, AB11 5RG, Aberdeen', 'addressInfo': {'address1': 'Union Square', 'address2': 'Guild Square', 'address3': None, 'address4': None, 'city': 'Aberdeen', 'state': 
# ...

# %%
# Date
available_dates = cinema.available_dates
cinema_dates = available_dates.filter_by(year=2018)
for i in range(len(cinema_dates)):
    print(i)
    print(cinema_dates[i].weekday)
    print(cinema_dates[i].date)
    break
select_date = int(input('Enter date:')) or 1
cinema_date = cinema_dates[select_date]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-654f798a8687> in <module>
#       1 # Date
# ----> 2 available_dates = cinema.available_dates
#       3 cinema_dates = available_dates.filter_by(year=2018)
#       4 for i in range(len(cinema_dates)):
#       5     print(i)
#
# NameError: name 'cinema' is not defined

# %%
# Movies
